# %%
import pandas as pd
import numpy as np
import scipy.stats 
import streamlit as st
import matplotlib 
from matplotlib import pyplot as plt
import altair as alt
import plotly_express as px

# %%
df = pd.read_csv('vehicles_us.csv')
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
#       transmission    type paint_color  is_4wd date_posted  days_listed
# 0        automatic     SUV         NaN     1.0  2018-06-23           19
# 1        automatic  pickup       white     1.0  2018-10-19           50
# 2        automatic   sedan         red     NaN  2019-02-07           79
# 3        automatic  pickup         NaN     NaN  2019-03-22            9
# 4        automatic   sedan       black     NaN  2019-04-02           28
# ...            ...     ...         ...     ...         ...          ...
# 51520    automatic   sedan       black     NaN  2018-10-03           37
# 51521    automatic   sedan       white     NaN  2018-11-14           22
# 51522    automatic   sedan        blue     NaN  2018-11-15           32
# 51523    automatic   sedan       black     NaN  2018-07-02           71
# 51524    automatic   sedan         NaN     NaN  2018-06-05           10
#
# [51525 rows x 13 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %%
df.dropna(subset=['model_year'], inplace=True)
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# 5      14990      2014.0    chrysler 300  excellent        6.0  gas   57954.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
#       transmission    type paint_color  is_4wd date_posted  days_listed
# 0        automatic     SUV         NaN     1.0  2018-06-23           19
# 2        automatic   sedan         red     NaN  2019-02-07           79
# 3        automatic  pickup         NaN     NaN  2019-03-22            9
# 4        automatic   sedan       black     NaN  2019-04-02           28
# 5        automatic   sedan       black     1.0  2018-06-20           15
# ...            ...     ...         ...     ...         ...          ...
# 51520    automatic   sedan       black     NaN  2018-10-03           37
# 51521    automatic   sedan       white     NaN  2018-11-14           22
# 51522    automatic   sedan        blue     NaN  2018-11-15           32
# 51523    automatic   sedan       black     NaN  2018-07-02           71
# 51524    automatic   sedan         NaN     NaN  2018-06-05           10
#
# [47906 rows x 13 columns]

# %%
df['model_year']=df['model_year'].astype(int)
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400        2011          bmw x5       good        6.0  gas  145000.0
# 2       5500        2013  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500        2003      ford f-150       fair        8.0  gas       NaN
# 4      14900        2017    chrysler 200  excellent        4.0  gas   80903.0
# 5      14990        2014    chrysler 300  excellent        6.0  gas   57954.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249        2013   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700        2002     honda civic    salvage        4.0  gas  181500.0
# 51522   3950        2009  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455        2013  toyota corolla       good        4.0  gas  139573.0
# 51524   6300        2014   nissan altima       good        4.0  gas       NaN
#
#       transmission    type paint_color  is_4wd date_posted  days_listed
# 0        automatic     SUV         NaN     1.0  2018-06-23           19
# 2        automatic   sedan         red     NaN  2019-02-07           79
# 3        automatic  pickup         NaN     NaN  2019-03-22            9
# 4        automatic   sedan       black     NaN  2019-04-02           28
# 5        automatic   sedan       black     1.0  2018-06-20           15
# ...            ...     ...         ...     ...         ...          ...
# 51520    automatic   sedan       black     NaN  2018-10-03           37
# 51521    automatic   sedan       white     NaN  2018-11-14           22
# 51522    automatic   sedan        blue     NaN  2018-11-15           32
# 51523    automatic   sedan       black     NaN  2018-07-02           71
# 51524    automatic   sedan         NaN     NaN  2018-06-05           10
#
# [47906 rows x 13 columns]

# %%
df['cylinders'] = pd.to_numeric(df['cylinders'], errors='coerce')
df.dropna(subset=['cylinders'], inplace=True)
df.sample(10)
# Out:
#        price  model_year                          model  condition  cylinders  \
# 29108  18000        2018                    kia sorento   like new        6.0
# 26282  10995        2015                  nissan altima  excellent        4.0
# 15907  15998        2014                     gmc sierra  excellent        6.0
# 9726   19800        2014            chevrolet silverado       good        8.0
# 12928   1999        2002                 honda civic lx       good        4.0
# 35615   8200        2010               volkswagen jetta  excellent        5.0
# 34004   9495        2016                       kia soul  excellent        4.0
# 26749  45000        2008             chevrolet corvette       good        8.0
# 50635  14900        2014                  ford explorer  excellent        4.0
# 23422  25200        2014  chevrolet silverado 1500 crew       good        6.0
#
#          fuel  odometer transmission    type paint_color  is_4wd date_posted  \
# 29108     gas   66000.0    automatic     SUV         NaN     1.0  2018-09-23
# 26282     gas   61083.0    automatic   sedan       white     NaN  2018-08-30
# 15907     gas   23790.0    automatic   truck       white     NaN  2018-07-15
# 9726   diesel  150764.0    automatic   truck        grey     1.0  2018-11-27
# 12928     gas   95000.0    automatic   sedan      silver     NaN  2018-11-02
# 35615     gas   83156.0    automatic   sedan         NaN     NaN  2019-03-30
# 34004     gas  108761.0       manual   sedan        grey     NaN  2019-03-02
# 26749     gas   20484.0       manual   coupe         NaN     NaN  2018-07-07
# 50635     gas  115000.0    automatic     SUV       white     NaN  2018-06-22
# 23422     gas   85048.0    automatic  pickup      silver     1.0  2018-11-23
#
#        days_listed
# 29108           18
# 26282           49
# 15907           30
# 9726            17
# 12928           14
# 35615           15
# 34004            3
# 26749           64
# 50635           11
# 23422           82

# %%
df.dropna(subset=['odometer'], inplace=True)
df['odometer']=df['odometer'].astype(int)
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400        2011          bmw x5       good        6.0  gas    145000
# 2       5500        2013  hyundai sonata   like new        4.0  gas    110000
# 4      14900        2017    chrysler 200  excellent        4.0  gas     80903
# 5      14990        2014    chrysler 300  excellent        6.0  gas     57954
# 6      12990        2015    toyota camry  excellent        4.0  gas     79212
# ...      ...         ...             ...        ...        ...  ...       ...
# 51518   3750        2005     ford taurus  excellent        6.0  gas    110200
# 51520   9249        2013   nissan maxima   like new        6.0  gas     88136
# 51521   2700        2002     honda civic    salvage        4.0  gas    181500
# 51522   3950        2009  hyundai sonata  excellent        4.0  gas    128000
# 51523   7455        2013  toyota corolla       good        4.0  gas    139573
#
#       transmission   type paint_color  is_4wd date_posted  days_listed
# 0        automatic    SUV         NaN     1.0  2018-06-23           19
# 2        automatic  sedan         red     NaN  2019-02-07           79
# 4        automatic  sedan       black     NaN  2019-04-02           28
# 5        automatic  sedan       black     1.0  2018-06-20           15
# 6        automatic  sedan       white     NaN  2018-12-27           73
# ...            ...    ...         ...     ...         ...          ...
# 51518    automatic  sedan      silver     NaN  2018-08-10           63
# 51520    automatic  sedan       black     NaN  2018-10-03           37
# 51521    automatic  sedan       white     NaN  2018-11-14           22
# 51522    automatic  sedan        blue     NaN  2018-11-15           32
# 51523    automatic  sedan       black     NaN  2018-07-02           71
#
# [36419 rows x 13 columns]

# %%
df['paint_color']=df['paint_color'].fillna('missing')
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400        2011          bmw x5       good        6.0  gas    145000
# 2       5500        2013  hyundai sonata   like new        4.0  gas    110000
# 4      14900        2017    chrysler 200  excellent        4.0  gas     80903
# 5      14990        2014    chrysler 300  excellent        6.0  gas     57954
# 6      12990        2015    toyota camry  excellent        4.0  gas     79212
# ...      ...         ...             ...        ...        ...  ...       ...
# 51518   3750        2005     ford taurus  excellent        6.0  gas    110200
# 51520   9249        2013   nissan maxima   like new        6.0  gas     88136
# 51521   2700        2002     honda civic    salvage        4.0  gas    181500
# 51522   3950        2009  hyundai sonata  excellent        4.0  gas    128000
# 51523   7455        2013  toyota corolla       good        4.0  gas    139573
#
#       transmission   type paint_color  is_4wd date_posted  days_listed
# 0        automatic    SUV     missing     1.0  2018-06-23           19
# 2        automatic  sedan         red     NaN  2019-02-07           79
# 4        automatic  sedan       black     NaN  2019-04-02           28
# 5        automatic  sedan       black     1.0  2018-06-20           15
# 6        automatic  sedan       white     NaN  2018-12-27           73
# ...            ...    ...         ...     ...         ...          ...
# 51518    automatic  sedan      silver     NaN  2018-08-10           63
# 51520    automatic  sedan       black     NaN  2018-10-03           37
# 51521    automatic  sedan       white     NaN  2018-11-14           22
# 51522    automatic  sedan        blue     NaN  2018-11-15           32
# 51523    automatic  sedan       black     NaN  2018-07-02           71
#
# [36419 rows x 13 columns]

# %%
df['is_4wd']=df['is_4wd'].fillna('no')
df['is_4wd'] = df['is_4wd'].replace(1.0, 'yes')
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400        2011          bmw x5       good        6.0  gas    145000
# 2       5500        2013  hyundai sonata   like new        4.0  gas    110000
# 4      14900        2017    chrysler 200  excellent        4.0  gas     80903
# 5      14990        2014    chrysler 300  excellent        6.0  gas     57954
# 6      12990        2015    toyota camry  excellent        4.0  gas     79212
# ...      ...         ...             ...        ...        ...  ...       ...
# 51518   3750        2005     ford taurus  excellent        6.0  gas    110200
# 51520   9249        2013   nissan maxima   like new        6.0  gas     88136
# 51521   2700        2002     honda civic    salvage        4.0  gas    181500
# 51522   3950        2009  hyundai sonata  excellent        4.0  gas    128000
# 51523   7455        2013  toyota corolla       good        4.0  gas    139573
#
#       transmission   type paint_color is_4wd date_posted  days_listed
# 0        automatic    SUV     missing    yes  2018-06-23           19
# 2        automatic  sedan         red     no  2019-02-07           79
# 4        automatic  sedan       black     no  2019-04-02           28
# 5        automatic  sedan       black    yes  2018-06-20           15
# 6        automatic  sedan       white     no  2018-12-27           73
# ...            ...    ...         ...    ...         ...          ...
# 51518    automatic  sedan      silver     no  2018-08-10           63
# 51520    automatic  sedan       black     no  2018-10-03           37
# 51521    automatic  sedan       white     no  2018-11-14           22
# 51522    automatic  sedan        blue     no  2018-11-15           32
# 51523    automatic  sedan       black     no  2018-07-02           71
#
# [36419 rows x 13 columns]

# %%
df['date_posted'] = pd.to_datetime(df['date_posted'])
df['date_posted'] = df['date_posted'].dt.strftime('%m/%d/%Y')
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400        2011          bmw x5       good        6.0  gas    145000
# 2       5500        2013  hyundai sonata   like new        4.0  gas    110000
# 4      14900        2017    chrysler 200  excellent        4.0  gas     80903
# 5      14990        2014    chrysler 300  excellent        6.0  gas     57954
# 6      12990        2015    toyota camry  excellent        4.0  gas     79212
# ...      ...         ...             ...        ...        ...  ...       ...
# 51518   3750        2005     ford taurus  excellent        6.0  gas    110200
# 51520   9249        2013   nissan maxima   like new        6.0  gas     88136
# 51521   2700        2002     honda civic    salvage        4.0  gas    181500
# 51522   3950        2009  hyundai sonata  excellent        4.0  gas    128000
# 51523   7455        2013  toyota corolla       good        4.0  gas    139573
#
#       transmission   type paint_color is_4wd date_posted  days_listed
# 0        automatic    SUV     missing    yes  06/23/2018           19
# 2        automatic  sedan         red     no  02/07/2019           79
# 4        automatic  sedan       black     no  04/02/2019           28
# 5        automatic  sedan       black    yes  06/20/2018           15
# 6        automatic  sedan       white     no  12/27/2018           73
# ...            ...    ...         ...    ...         ...          ...
# 51518    automatic  sedan      silver     no  08/10/2018           63
# 51520    automatic  sedan       black     no  10/03/2018           37
# 51521    automatic  sedan       white     no  11/14/2018           22
# 51522    automatic  sedan        blue     no  11/15/2018           32
# 51523    automatic  sedan       black     no  07/02/2018           71
#
# [36419 rows x 13 columns]

# %%
df['price']=df['price'].astype(float)
df
# Out:
#          price  model_year           model  condition  cylinders fuel  \
# 0       9400.0        2011          bmw x5       good        6.0  gas
# 2       5500.0        2013  hyundai sonata   like new        4.0  gas
# 4      14900.0        2017    chrysler 200  excellent        4.0  gas
# 5      14990.0        2014    chrysler 300  excellent        6.0  gas
# 6      12990.0        2015    toyota camry  excellent        4.0  gas
# ...        ...         ...             ...        ...        ...  ...
# 51518   3750.0        2005     ford taurus  excellent        6.0  gas
# 51520   9249.0        2013   nissan maxima   like new        6.0  gas
# 51521   2700.0        2002     honda civic    salvage        4.0  gas
# 51522   3950.0        2009  hyundai sonata  excellent        4.0  gas
# 51523   7455.0        2013  toyota corolla       good        4.0  gas
#
#        odometer transmission   type paint_color is_4wd date_posted  \
# 0        145000    automatic    SUV     missing    yes  06/23/2018
# 2        110000    automatic  sedan         red     no  02/07/2019
# 4         80903    automatic  sedan       black     no  04/02/2019
# 5         57954    automatic  sedan       black    yes  06/20/2018
# 6         79212    automatic  sedan       white     no  12/27/2018
# ...         ...          ...    ...         ...    ...         ...
# 51518    110200    automatic  sedan      silver     no  08/10/2018
# 51520     88136    automatic  sedan       black     no  10/03/2018
# 51521    181500    automatic  sedan       white     no  11/14/2018
# 51522    128000    automatic  sedan        blue     no  11/15/2018
# 51523    139573    automatic  sedan       black     no  07/02/2018
#
#        days_listed
# 0               19
# 2               79
# 4               28
# 5               15
# 6               73
# ...            ...
# 51518           63
# 51520           37
# 51521           22
# 51522           32
# 51523           71
#
# [36419 rows x 13 columns]

# %%
df['manufacturer']=df['model'].apply(lambda x:x.split()[0])
df
# Out:
#          price  model_year           model  condition  cylinders fuel  \
# 0       9400.0        2011          bmw x5       good        6.0  gas
# 2       5500.0        2013  hyundai sonata   like new        4.0  gas
# 4      14900.0        2017    chrysler 200  excellent        4.0  gas
# 5      14990.0        2014    chrysler 300  excellent        6.0  gas
# 6      12990.0        2015    toyota camry  excellent        4.0  gas
# ...        ...         ...             ...        ...        ...  ...
# 51518   3750.0        2005     ford taurus  excellent        6.0  gas
# 51520   9249.0        2013   nissan maxima   like new        6.0  gas
# 51521   2700.0        2002     honda civic    salvage        4.0  gas
# 51522   3950.0        2009  hyundai sonata  excellent        4.0  gas
# 51523   7455.0        2013  toyota corolla       good        4.0  gas
#
#        odometer transmission   type paint_color is_4wd date_posted  \
# 0        145000    automatic    SUV     missing    yes  06/23/2018
# 2        110000    automatic  sedan         red     no  02/07/2019
# 4         80903    automatic  sedan       black     no  04/02/2019
# 5         57954    automatic  sedan       black    yes  06/20/2018
# 6         79212    automatic  sedan       white     no  12/27/2018
# ...         ...          ...    ...         ...    ...         ...
# 51518    110200    automatic  sedan      silver     no  08/10/2018
# 51520     88136    automatic  sedan       black     no  10/03/2018
# 51521    181500    automatic  sedan       white     no  11/14/2018
# 51522    128000    automatic  sedan        blue     no  11/15/2018
# 51523    139573    automatic  sedan       black     no  07/02/2018
#
#        days_listed manufacturer
# 0               19          bmw
# 2               79      hyundai
# 4               28     chrysler
# 5               15     chrysler
# 6               73       toyota
# ...            ...          ...
# 51518           63         ford
# 51520           37       nissan
# 51521           22        honda
# 51522           32      hyundai
# 51523           71       toyota
#
# [36419 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# manufacturer    0
# dtype: int64

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#          price  model_year           model  condition  cylinders fuel  \
# 0       9400.0        2011          bmw x5       good        6.0  gas
# 1       5500.0        2013  hyundai sonata   like new        4.0  gas
# 2      14900.0        2017    chrysler 200  excellent        4.0  gas
# 3      14990.0        2014    chrysler 300  excellent        6.0  gas
# 4      12990.0        2015    toyota camry  excellent        4.0  gas
# ...        ...         ...             ...        ...        ...  ...
# 36414   3750.0        2005     ford taurus  excellent        6.0  gas
# 36415   9249.0        2013   nissan maxima   like new        6.0  gas
# 36416   2700.0        2002     honda civic    salvage        4.0  gas
# 36417   3950.0        2009  hyundai sonata  excellent        4.0  gas
# 36418   7455.0        2013  toyota corolla       good        4.0  gas
#
#        odometer transmission   type paint_color is_4wd date_posted  \
# 0        145000    automatic    SUV     missing    yes  06/23/2018
# 1        110000    automatic  sedan         red     no  02/07/2019
# 2         80903    automatic  sedan       black     no  04/02/2019
# 3         57954    automatic  sedan       black    yes  06/20/2018
# 4         79212    automatic  sedan       white     no  12/27/2018
# ...         ...          ...    ...         ...    ...         ...
# 36414    110200    automatic  sedan      silver     no  08/10/2018
# 36415     88136    automatic  sedan       black     no  10/03/2018
# 36416    181500    automatic  sedan       white     no  11/14/2018
# 36417    128000    automatic  sedan        blue     no  11/15/2018
# 36418    139573    automatic  sedan       black     no  07/02/2018
#
#        days_listed manufacturer
# 0               19          bmw
# 1               79      hyundai
# 2               28     chrysler
# 3               15     chrysler
# 4               73       toyota
# ...            ...          ...
# 36414           63         ford
# 36415           37       nissan
# 36416           22        honda
# 36417           32      hyundai
# 36418           71       toyota
#
# [36419 rows x 14 columns]

# %%
fig = px.histogram(df, x='price', title='Price Distribution')
fig.show()

# %%
st.header('Data viewer') 
st.dataframe(df)
# Out:
# DeltaGenerator()

# %%
# Out:
# DeltaGenerator()
